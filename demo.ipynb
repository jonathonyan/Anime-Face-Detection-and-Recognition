# %%
from main import *

# %%
img = cv2.imread("./datasets/sample1.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
scale = 1
img_in, img_out = pre_process_image(img, scale)
img_out_2 = np.copy(img_out)
img_out, bounding_boxes = detect_main(img_in, img_out, None, scale, False, False)
img_out = cv2.cvtColor(img_out, cv2.COLOR_BGR2RGB)
plt.imshow(img_out)

# %%
img = cv2.imread("./datasets/sample2.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
scale = 0.5
img_in, img_out = pre_process_image(img, scale)
img_out_2 = np.copy(img_out)
img_out, bounding_boxes = detect_main(img_in, img_out, None, scale, False, False)
img_out = cv2.cvtColor(img_out, cv2.COLOR_BGR2RGB)
plt.imshow(img_out)

# %%
img_out_2 = recognize_main(img_in, img_out_2, None, scale, False, False, bounding_boxes)
# Out:
# The Network is Loaded
# recognize
# (284, 320, 3)
# (48, 56, 224, 224)
# classes =  ['10', '9', '3', '1', '8', '6', '4', '2', '5', '7']
# ==================================================================
# the top possible characters are :
# izumi_konata ( Possibility = 0.902944028377533 )
# hakurei_reimu ( Possibility = 0.04625469073653221 )
# suzumiya_haruhi ( Possibility = 0.042435891926288605 )
# hatsune_miku ( Possibility = 0.003990592435002327 )
# shana ( Possibility = 0.0025082938373088837 )
# lelouch_lamperouge ( Possibility = 0.0012140199542045593 )
# fate_testarossa ( Possibility = 0.00023210636572912335 )
# kinomoto_sakura ( Possibility = 0.00018477394769433886 )
# takamachi_nanoha ( Possibility = 0.00012687488924711943 )
# akiyama_mio ( Possibility = 0.00010848583042388782 )

# %%
img_out_2 = cv2.cvtColor(img_out_2, cv2.COLOR_BGR2RGB)
plt.imshow(img_out_2)
